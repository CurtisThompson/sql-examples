# %% [markdown]
# # Set-Up

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('../data/data.db')
c = conn.cursor()

def execute_statement(statement):
    c.execute(statement)
    res = c.fetchall()
    column_names = [description[0] for description in c.description]
    return pd.DataFrame(res, columns=column_names)

# %% [markdown]
# # DISTINCT
# To get unique values of a given column, use the DISTINCT statement.

# %%
execute_statement('SELECT * FROM LeicestershireBirds INNER JOIN cites ON LeicestershireBirds.Taxon = cites.Taxon')
# Out:
#       Category             Name  Status  Rarity Winter  Rarity Summer  \
# 0            C   Egyptian Goose  F4; B3              0              0
# 1            C   Egyptian Goose  F4; B3              0              0
# 2            C   Egyptian Goose  F4; B3              0              0
# 3            C   Egyptian Goose  F4; B3              0              0
# 4            C   Egyptian Goose  F4; B3              0              0
# ...        ...              ...     ...            ...            ...
# 38746        A  Short-eared Owl      W4              4              0
# 38747        A  Short-eared Owl      W4              4              0
# 38748        A  Short-eared Owl      W4              4              0
# 38749        A  Short-eared Owl      W4              4              0
# 38750        A  Short-eared Owl      W4              4              0
#
#        Rarity Breeding  Rarity Passage  Rarity Vagrant  Rarity Feral  \
# 0                    3               0               0             4
# 1                    3               0               0             4
# 2                    3               0               0             4
# 3                    3               0               0             4
# 4                    3               0               0             4
# ...                ...             ...             ...           ...
# 38746                0               0               0             0
# 38747                0               0               0             0
# 38748                0               0               0             0
# 38749                0               0               0             0
# 38750                0               0               0             0
#
#        Rarity Escapee  ...  Unit Importer  Exporter  Origin Purpose Source  \
# 0                   0  ...  None       US        ZA    None       H      W
# 1                   0  ...  None       DE        ZW    None       T      W
# 2                   0  ...  None       US        ZA    None       H      W
# 3                   0  ...  None       US        ZA    None       H      W
# 4                   0  ...  None       CS        NL    None       T      C
# ...               ...  ...   ...      ...       ...     ...     ...    ...
# 38746               0  ...  None       AT        US    None       S      W
# 38747               0  ...  None       AU        GB      GB       T      U
# 38748               0  ...  None       US        EC    None       S      W
# 38749               0  ...  None       JP        UZ    None       T      W
# 38750               0  ...  None       US        EC    None       S      W
#
#       Reporter.type Import.permit.RandomID Export.permit.RandomID  \
# 0                 E                   None             da69ac58ca
# 1                 E                   None             061e821b54
# 2                 E                   None             aebb86d3cd
# 3                 E                   None             560c36119c
# 4                 E                   None             c7559a60a6
# ...             ...                    ...                    ...
# 38746             E                   None             3f2d2e12c7
# 38747             E                   None             1e8cf2590e
# 38748             E                   None             f56e2d1794
# 38749             E                   None             c86a753858
# 38750             E                   None             09904d77b6
#
#       Origin.permit.RandomID
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 38746                   None
# 38747                   None
# 38748                   None
# 38749                   None
# 38750                   None
#
# [38751 rows x 32 columns]
