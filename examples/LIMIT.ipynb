# %% [markdown]
# # Set-Up

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('../data/data.db')
c = conn.cursor()

def execute_statement(statement):
    c.execute(statement)
    res = c.fetchall()
    column_names = [description[0] for description in c.description]
    return pd.DataFrame(res, columns=column_names)

# %% [markdown]
# # LIMIT

# %%
execute_statement('SELECT * FROM cites LIMIT 5')
# Out:
#           Id  Year Appendix                       Taxon Class           Order  \
# 0  898586291  2001       II             Nandayus nenday  Aves  Psittaciformes
# 1  551195871  2001       II             Nandayus nenday  Aves  Psittaciformes
# 2  597857621  2000       II  Psittacus erithacus timneh  Aves  Psittaciformes
# 3  367154901  2001       II  Psittacus erithacus timneh  Aves  Psittaciformes
# 4  286394641  2001       II  Psittacus erithacus timneh  Aves  Psittaciformes
#
#         Family      Genus  Term  Quantity  Unit Importer Exporter Origin  \
# 0  Psittacidae   Nandayus  live       1.0  None       ZA       CI     XX
# 1  Psittacidae   Nandayus  live       1.0  None       ZA       CI     XX
# 2  Psittacidae  Psittacus  live      40.0  None       ES       CI   None
# 3  Psittacidae  Psittacus  live     100.0  None       ZA       CI   None
# 4  Psittacidae  Psittacus  live     100.0  None       ZA       CI   None
#
#   Purpose Source Reporter.type Import.permit.RandomID Export.permit.RandomID  \
# 0       P      W             I             b459656686             1f7d1fe027
# 1       P      W             E                   None             c2061517c7
# 2       T      W             I                   None             9b0e308107
# 3       T      W             E                   None             4b5c826fe9
# 4       T      W             I             a490668140             7d3ba372ba
#
#   Origin.permit.RandomID
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
